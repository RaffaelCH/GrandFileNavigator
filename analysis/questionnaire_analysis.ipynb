# %% [markdown]
# # Questionnaire Analysis
#
# Code to analyze the questionnaire responses: calculate metrics, match them to tasks.

# %%
from shared import *
import pandas


def map_agreement(agreement):
    if agreement == "Strongly agree":
        return 5
    elif agreement == "Agree":
        return 4
    elif agreement == "Neutral":
        return 3
    elif agreement == "Disagree":
        return 2
    elif agreement == "Strongly disagree":
        return 1
    return agreement


evaluation_data = pandas.read_csv("./questionnaire_data/Evaluation_Feedback.csv")
overall_data = pandas.read_csv("./questionnaire_data/Overall_Feedback.csv")

print(evaluation_data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 9
#       5 if parent_dir not in sys.path:
#       6     sys.path.append(parent_dir)
# ----> 9 from ..shared import *
#      10 import pandas
#      13 def map_agreement(agreement):
#
# ImportError: attempted relative import with no known parent package
